# %% [markdown]
# ## Melbourne Housing Prices
# The goal of this notebook is to predict future house prices in Melbourne.
#
# ### Question
# How will future housing prices change?
#
# ### Features of the dataset
# * Rooms
# * Price
# * Distance
# * Postcode
# * Bedroom2
# * Bathroom
# * Car
# * Landsize
# * BuildingArea
# * YearBuilt
# * Lattitude
# * Longtitude
# * Propertycount

# %%
import pandas as pd
import numpy as np
import statistics
import matplotlib
# %matplotlib inline

# %%
# import housing dataset
data_path = "dataset/melb_data.csv"
housing_data = pd.read_csv(data_path)

# %% [markdown]
# ## >> -- EDA -- <

# %%
# let's get a glimpse at the data
housing_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
housing_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
housing_data.tail()
# Out:
#               Suburb        Address  Rooms Type      Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %% [markdown]
# ### >> Observe <<
# Notice how columns __BuildingArea__ and __CouncilArea__ have quite a few null values. Let's drop any missing (na) values from rows.

# %%
housing_data.dropna(axis=0, inplace=True)

# %%
housing_data.head()
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 4  Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
# 6  Abbotsford     124 Yarra St      3    h  1876000.0      S  Nelson
# 7  Abbotsford    98 Charles St      2    h  1636000.0      S  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
# 6  7/05/2016       2.5    3067.0  ...       2.0  0.0     245.0         210.0
# 7  8/10/2016       2.5    3067.0  ...       1.0  2.0     256.0         107.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
housing_data.tail()
# Out:
#              Suburb          Address  Rooms Type      Price Method  \
# 12205    Whittlesea    30 Sherwin St      3    h   601000.0      S
# 12206  Williamstown      75 Cecil St      3    h  1050000.0     VB
# 12207  Williamstown    2/29 Dover Rd      1    u   385000.0     SP
# 12209       Windsor  201/152 Peel St      2    u   560000.0     PI
# 12212    Yarraville  54 Pentland Pde      6    h  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 12205            Ray  29/07/2017      35.5    3757.0  ...       2.0  1.0
# 12206       Williams  29/07/2017       6.8    3016.0  ...       1.0  0.0
# 12207       Williams  29/07/2017       6.8    3016.0  ...       1.0  1.0
# 12209  hockingstuart  29/07/2017       4.6    3181.0  ...       1.0  1.0
# 12212        Village  29/07/2017       6.3    3013.0  ...       3.0  2.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %% [markdown]
# ### >> Choosing a Predition Target <<
# Remember our goal is to predict the price of house prices. This is our target. We will call this (y).

# %%
y = housing_data.Price

# %% [markdown]
# ### >> Selecting Features <<
# Next we want to choose features (or columns) needed to feed our model. We will call this list of features (x).

# %%
# The most important features for determining price in our case will be Bathroom, Landsize, Location (Latitude, Longitude), Rooms.
melbourne_features = ["Rooms", "Bathroom", "Landsize", "Lattitude", "Longtitude"]
x = housing_data[melbourne_features]

# %%
# let's get a summary of the feature data
x.describe()
# Out:
#              Rooms     Bathroom      Landsize    Lattitude   Longtitude
# count  6196.000000  6196.000000   6196.000000  6196.000000  6196.000000
# mean      2.931407     1.576340    471.006940   -37.807904   144.990201
# std       0.971079     0.711362    897.449881     0.075850     0.099165
# min       1.000000     1.000000      0.000000   -38.164920   144.542370
# 25%       2.000000     1.000000    152.000000   -37.855438   144.926198
# 50%       3.000000     1.000000    373.000000   -37.802250   144.995800
# 75%       4.000000     2.000000    628.000000   -37.758200   145.052700
# max       8.000000     8.000000  37000.000000   -37.457090   145.526350

# %%
x.head()
# Out:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 4      4       1.0     120.0   -37.8072    144.9941
# 6      3       2.0     245.0   -37.8024    144.9993
# 7      2       1.0     256.0   -37.8060    144.9954

# %% [markdown]
# ## >> -- Build Model -- <<
# Now we will create our model using scikit-learn library.
#
# 1. DEFINE the type of model
# 2. FIT patterns from the data
# 3. PREDICT
# 4. EVALUATE how accurate the model predictions are

# %%
# necessary for creating models.
from sklearn.tree import DecisionTreeRegressor

# %%
# define model
melbourne_model = DecisionTreeRegressor(random_state = 1)

# fit model using features, target variable
melbourne_model.fit(x, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print("Predictions for the following 5 houses: ")
print(x.head())
# Out:
# Predictions for the following 5 houses:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 4      4       1.0     120.0   -37.8072    144.9941
# 6      3       2.0     245.0   -37.8024    144.9993
# 7      2       1.0     256.0   -37.8060    144.9954

# %%
print("Price Predictions:")
print(melbourne_model.predict(x.head()))
# Out:
# Price Predictions:
# [1035000. 1465000. 1600000. 1876000. 1636000.]

# %%
print("Actual price of above homes: ")
y.head()
# Out:
# Actual price of above homes:
# 1    1035000.0
# 2    1465000.0
# 4    1600000.0
# 6    1876000.0
# 7    1636000.0
# Name: Price, dtype: float64

# %% [markdown]
# ## >> -- Model Validation -- <<

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# #### -> In-Sample <-

# %%
insample_prediction = melbourne_model.predict(x)

mean_absolute_error(y, insample_prediction)
# Out:
# 69826.38858403271

# %% [markdown]
# #### -> Out of Sample <-

# %%
# randomly break up data into training and test data
# val_x = features
# val_y = target
train_x, val_x, train_y, val_y = train_test_split(x, y, random_state = 0)

# %%
# define model
melbourne_model = DecisionTreeRegressor()

# fit model to train data
melbourne_model.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor()

# %%
# get predicted prices on validation data
val_predictions = melbourne_model.predict(val_x)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 275890.0075317409
